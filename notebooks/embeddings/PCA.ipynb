# %%
import sys
sys.path.insert(0, '../../src')
from utils import preprocession as prep
from utils.metrics import compute_metric, add_to_metrics, columns

import os
import pickle
import pandas as pd
import numpy as np

from sklearn import decomposition as mf

from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# ## PCA with Matrix Factorization

# %%
def evaluatePCA(folder_name, data_name):

    train, test = prep.load_data(folder_name, data_name)
    _, train_reactions = train
    _, test_reactions = test

    method_path = f"../../embeddings/PCA/{folder_name}/{data_name}"
    output_path = f"../../embeddings/PCA/{folder_name}/{data_name}/MF"
    os.makedirs(output_path, exist_ok=True)

    metrics = []
    for p in tqdm(train_reactions.keys()):
        train_data = prep.impute_dataframe(train_reactions[p])
        pca = mf.PCA(n_components=2).fit(train_data)
        with open(f'{method_path}/PCA_{p}.pkl', 'wb') as file:
            pickle.dump(pca, file)

        X = pd.DataFrame(pca.transform(train_data),
                         index=train_reactions[p].index, columns=['x','y'])
        X.to_csv(f'{method_path}/train_embedding_{p}.csv')

        train_predictions = pd.DataFrame(pca.inverse_transform(X.values),
                                index=train_data.index, columns=train_data.columns)
        train_predictions.to_csv(f'{output_path}/train_predictions_{p}.csv')
        train_result = compute_metric(train_predictions, train_reactions[0], train_reactions[p].isna(), silent=True)
        add_to_metrics(metrics, train_result, [folder_name, data_name, 'Train', p, 'Train', p, 'PCA', 'Matrix Factorization'])

        test_list = test_reactions.keys() if p == 0 else [p]
        for q in test_list:
            test_data  = prep.impute_dataframe(test_reactions[q], mean=train_data.mean())

            Y = pd.DataFrame(pca.transform(test_data), 
                             index=test_reactions[p].index, columns=['x','y'])
            Y.to_csv(f'{method_path}/test_embedding_{p}_{q}.csv')

            test_predictions  = pd.DataFrame(pca.inverse_transform(Y.values),
                                             index=test_data.index, columns=test_data.columns)
            test_predictions.to_csv(f'{output_path}/test_predictions_{p}_{q}.csv')

            test_result = compute_metric(test_predictions, test_reactions[0], test_reactions[q].isna(), silent=True)
            add_to_metrics(metrics, test_result, [folder_name, data_name, 'Train', p, 'Test', q, 'PCA', 'Matrix Factorization'])

    metrics = pd.DataFrame(metrics, columns=columns)
    metrics.to_csv(f'{output_path}/metrics.csv')
    return metrics

# %% [markdown]
# ## Datasets
#
# ### Smartvote Original

# %%
metrics = evaluatePCA(folder_name = 'Smartvote', data_name = 'Original')
metrics.sample(5)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#       Dataset  Datatype Train Set  Train Sparsity Evaluation Set  \
# 71  Smartvote  Original     Train              80          Train
# 18  Smartvote  Original     Train               0          Train
# 5   Smartvote  Original     Train              60           Test
# 82  Smartvote  Original     Train              50          Train
# 65  Smartvote  Original     Train              40          Train
#
#     Evaluation Sparsity Embedding Method     Prediction Method     Task  \
# 71                   80              PCA  Matrix Factorization  Overall
# 18                    0              PCA  Matrix Factorization      Fit
# 5                    60              PCA  Matrix Factorization  Overall
# 82                   50              PCA  Matrix Factorization   Impute
# 65                   40              PCA  Matrix Factorization  Overall
#
#     Accuracy      RMSE
# 71  0.725442  0.333859
# 18  0.814262  0.260816
# 5   0.770253  0.304135
# 82  0.778198  0.296063
# 65  0.795101  0.281849

# %% [markdown]
# ### Smartvote Binary

# %%
metrics = evaluatePCA(folder_name = 'Smartvote', data_name = 'Binary')
metrics.sample(5)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#       Dataset Datatype Train Set  Train Sparsity Evaluation Set  \
# 74  Smartvote   Binary     Train              80           Test
# 45  Smartvote   Binary     Train               0           Test
# 32  Smartvote   Binary     Train               0           Test
# 44  Smartvote   Binary     Train               0           Test
# 67  Smartvote   Binary     Train              40           Test
#
#     Evaluation Sparsity Embedding Method     Prediction Method     Task  \
# 74                   80              PCA  Matrix Factorization  Overall
# 45                   70              PCA  Matrix Factorization      Fit
# 32                   80              PCA  Matrix Factorization  Overall
# 44                    0              PCA  Matrix Factorization  Overall
# 67                   40              PCA  Matrix Factorization   Impute
#
#     Accuracy      RMSE
# 74  0.731494  0.424833
# 45  0.774813  0.399551
# 32  0.737149  0.422735
# 44  0.825793  0.352643
# 67  0.797356  0.379341

# %% [markdown]
# ### Synthetic Multiclass

# %%
metrics = evaluatePCA(folder_name = 'Synthetic_60_50', data_name = 'Original')
metrics.sample(5)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#             Dataset  Datatype Train Set  Train Sparsity Evaluation Set  \
# 60  Synthetic_60_50  Original     Train              30           Test
# 85  Synthetic_60_50  Original     Train              50           Test
# 73  Synthetic_60_50  Original     Train              80           Test
# 77  Synthetic_60_50  Original     Train              90          Train
# 75  Synthetic_60_50  Original     Train              90          Train
#
#     Evaluation Sparsity Embedding Method     Prediction Method     Task  \
# 60                   30              PCA  Matrix Factorization      Fit
# 85                   50              PCA  Matrix Factorization   Impute
# 73                   80              PCA  Matrix Factorization   Impute
# 77                   90              PCA  Matrix Factorization  Overall
# 75                   90              PCA  Matrix Factorization      Fit
#
#     Accuracy      RMSE
# 60  0.941429  0.168581
# 85  0.886000  0.225179
# 73  0.744167  0.310785
# 77  0.688750  0.330956
# 75  0.757500  0.298130

# %% [markdown]
# ### Synthetic Binary

# %%
metrics = evaluatePCA(folder_name = 'Synthetic_60_50', data_name = 'Binary')
metrics.sample(5)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#             Dataset Datatype Train Set  Train Sparsity Evaluation Set  \
# 85  Synthetic_60_50   Binary     Train              50           Test
# 81  Synthetic_60_50   Binary     Train              50          Train
# 39  Synthetic_60_50   Binary     Train               0           Test
# 64  Synthetic_60_50   Binary     Train              40          Train
# 71  Synthetic_60_50   Binary     Train              80          Train
#
#     Evaluation Sparsity Embedding Method     Prediction Method     Task  \
# 85                   50              PCA  Matrix Factorization   Impute
# 81                   50              PCA  Matrix Factorization      Fit
# 39                   60              PCA  Matrix Factorization      Fit
# 64                   40              PCA  Matrix Factorization   Impute
# 71                   80              PCA  Matrix Factorization  Overall
#
#     Accuracy      RMSE
# 85  0.892000  0.329213
# 81  0.906667  0.311505
# 39  0.884167  0.334888
# 64  0.901042  0.310813
# 71  0.776000  0.405007
