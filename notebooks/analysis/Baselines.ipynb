# %%
import sys
sys.path.insert(0, '../../src')
from utils import preprocession as prep
from utils.metrics import compute_metric, add_to_metrics, columns

import os
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# ### Baselines

# %%
def evaluateBaseline(folder_name, data_name):

    train, test = prep.load_data(folder_name, data_name)
    _, train_reactions = train
    _, test_reactions = test
    
    metrics = []
    for p in train_reactions.keys():
        train_predictions = prep.impute_dataframe(train_reactions[p])
        train_result = compute_metric(train_predictions, train_reactions[0], train_reactions[p].isna(), silent=True)
        add_to_metrics(metrics, train_result, [folder_name, data_name, 'Train', p, 'Train', p, 'Baseline', 'Mean'])

        test_list = test_reactions.keys() if p == 0 else [p]
        for q in test_list:
            test_predictions  = prep.impute_dataframe(test_reactions[q], mean=train_predictions.mean())
            test_result = compute_metric(test_predictions, test_reactions[0], test_reactions[q].isna(), silent=True)
            add_to_metrics(metrics, test_result, [folder_name, data_name, 'Train', p, 'Test', q, 'Baseline', 'Mean'])

    metrics = pd.DataFrame(metrics, columns=columns)
    return metrics

# %% [markdown]
# ## Datasets
#
# ### Smartvote Original

# %%
metrics_1 = evaluateBaseline(folder_name = 'Smartvote', data_name = 'Original')
metrics_1
# Out:
#       Dataset  Datatype Train Set  Train Sparsity Evaluation Set  \
# 0   Smartvote  Original     Train              60          Train
# 1   Smartvote  Original     Train              60          Train
# 2   Smartvote  Original     Train              60          Train
# 3   Smartvote  Original     Train              60           Test
# 4   Smartvote  Original     Train              60           Test
# ..        ...       ...       ...             ...            ...
# 82  Smartvote  Original     Train              50          Train
# 83  Smartvote  Original     Train              50          Train
# 84  Smartvote  Original     Train              50           Test
# 85  Smartvote  Original     Train              50           Test
# 86  Smartvote  Original     Train              50           Test
#
#     Evaluation Sparsity Embedding Method Prediction Method     Task  Accuracy  \
# 0                    60         Baseline              Mean      Fit  1.000000
# 1                    60         Baseline              Mean   Impute  0.668941
# 2                    60         Baseline              Mean  Overall  0.801365
# 3                    60         Baseline              Mean      Fit  1.000000
# 4                    60         Baseline              Mean   Impute  0.669502
# ..                  ...              ...               ...      ...       ...
# 82                   50         Baseline              Mean   Impute  0.673389
# 83                   50         Baseline              Mean  Overall  0.834517
# 84                   50         Baseline              Mean      Fit  1.000000
# 85                   50         Baseline              Mean   Impute  0.663884
# 86                   50         Baseline              Mean  Overall  0.829701
#
#             RMSE
# 0   3.932887e-18
# 1   3.663166e-01
# 2   2.197899e-01
# 3   3.822369e-18
# 4   3.669851e-01
# ..           ...
# 82  3.639723e-01
# 83  1.844126e-01
# 84  3.584899e-18
# 85  3.662570e-01
# 86  1.855702e-01
#
# [87 rows x 11 columns]

# %% [markdown]
# ### Smartvote Binary

# %%
metrics_2 = evaluateBaseline(folder_name = 'Smartvote', data_name = 'Binary')
metrics_2.sample(5)
# Out:
#       Dataset Datatype Train Set  Train Sparsity Evaluation Set  \
# 61  Smartvote   Binary     Train              30           Test
# 75  Smartvote   Binary     Train              90          Train
# 23  Smartvote   Binary     Train               0           Test
# 15  Smartvote   Binary     Train              10           Test
# 42  Smartvote   Binary     Train               0           Test
#
#     Evaluation Sparsity Embedding Method Prediction Method     Task  Accuracy  \
# 61                   30         Baseline              Mean   Impute  0.681034
# 75                   90         Baseline              Mean      Fit  1.000000
# 23                   20         Baseline              Mean  Overall  0.936368
# 15                   10         Baseline              Mean      Fit  1.000000
# 42                    0         Baseline              Mean      Fit  1.000000
#
#         RMSE
# 61  0.453742
# 75  0.000000
# 23  0.090811
# 15  0.000000
# 42  0.000000

# %% [markdown]
# ### Synthetic Multiclass

# %%
metrics_3 = evaluateBaseline(folder_name = 'Synthetic_60_50', data_name = 'Original')
metrics_3.sample(5)
# Out:
#             Dataset  Datatype Train Set  Train Sparsity Evaluation Set  \
# 1   Synthetic_60_50  Original     Train              60          Train
# 20  Synthetic_60_50  Original     Train               0          Train
# 62  Synthetic_60_50  Original     Train              30           Test
# 4   Synthetic_60_50  Original     Train              60           Test
# 64  Synthetic_60_50  Original     Train              40          Train
#
#     Evaluation Sparsity Embedding Method Prediction Method     Task  Accuracy  \
# 1                    60         Baseline              Mean   Impute  0.656250
# 20                    0         Baseline              Mean  Overall  1.000000
# 62                   30         Baseline              Mean  Overall  0.894667
# 4                    60         Baseline              Mean   Impute  0.646111
# 64                   40         Baseline              Mean   Impute  0.650417
#
#             RMSE
# 1   3.472185e-01
# 20  2.430264e-18
# 62  1.066601e-01
# 4   3.559876e-01
# 64  3.466178e-01

# %% [markdown]
# ### Synthetic Binary

# %%
metrics_4 = evaluateBaseline(folder_name = 'Synthetic_60_50', data_name = 'Binary')
metrics_4.sample(5)
# Out:
#             Dataset Datatype Train Set  Train Sparsity Evaluation Set  \
# 54  Synthetic_60_50   Binary     Train              20           Test
# 2   Synthetic_60_50   Binary     Train              60          Train
# 77  Synthetic_60_50   Binary     Train              90          Train
# 5   Synthetic_60_50   Binary     Train              60           Test
# 39  Synthetic_60_50   Binary     Train               0           Test
#
#     Evaluation Sparsity Embedding Method Prediction Method     Task  Accuracy  \
# 54                   20         Baseline              Mean      Fit  1.000000
# 2                    60         Baseline              Mean  Overall  0.795333
# 77                   90         Baseline              Mean  Overall  0.677250
# 5                    60         Baseline              Mean  Overall  0.789667
# 39                   60         Baseline              Mean      Fit  1.000000
#
#         RMSE
# 54  0.000000
# 2   0.274989
# 77  0.423066
# 5   0.277867
# 39  0.000000

# %%
pd.concat([metrics_1,metrics_2,metrics_3,metrics_4]).to_csv('../../results/baseline_metrics.csv')
